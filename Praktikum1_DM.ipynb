# %%
import pandas as pd
import numpy as np

# object creation
s = pd.Series([1, 3, 5, np.nan, 6, 8])
dates = pd.date_range('2023-10-01', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

print("Object Creation:")
print("Series:")
print(s)
print("\nDataFrame:")
print(df)
print("="*50)
# Out:
# Object Creation:
# Series:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
#
# DataFrame:
#                    A         B         C         D
# 2023-10-01 -0.524242 -0.821507  0.325064  0.851786
# 2023-10-02 -1.072816  0.967339 -0.053552  1.444969
# 2023-10-03 -0.396280  2.787754 -0.068282  0.384901
# 2023-10-04  2.951672 -0.391658 -0.299577 -1.154125
# 2023-10-05  0.057188  0.036190  0.866765  2.122833
# 2023-10-06 -0.790842 -0.213585 -1.531817 -2.501583
# ==================================================

# %%
# Viewing Data
print("Viewing Data:")
print("First 3 rows:")
print(df.head(3))
print("\nLast 2 rows:")
print(df.tail(2))
print("\nIndex and Columns:")
print(df.index)
print(df.columns)
print("="*40)
# Out:
# Viewing Data:
# First 3 rows:
#                    A         B         C         D
# 2023-10-01 -0.062937  0.372422 -0.576213 -1.677258
# 2023-10-02  0.382352 -0.245340 -0.115292  1.088438
# 2023-10-03 -3.315692 -0.135003 -1.218170  0.067759
#
# Last 2 rows:
#                    A         B         C         D
# 2023-10-05  0.046149 -1.280733 -0.108978  0.541765
# 2023-10-06  0.677412 -1.700209  0.602757  0.681643
#
# Index and Columns:
# DatetimeIndex(['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04',
#                '2023-10-05', '2023-10-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')
# ========================================

# %%
# Selection
print("Selection:")
print("Selecting a column (A):")
print(df['A'])
print("\nSelecting by label (row 0):")
print(df.loc[dates[0]])
print("\nSelecting by position (row 1):")
print(df.iloc[1])
print("\nSelecting a subset of rows and columns:")
print(df.loc[dates[1:3], ['A', 'B']])
print("="*40)
# Out:
# Selection:
# Selecting a column (A):
# 2023-10-01   -0.524242
# 2023-10-02   -1.072816
# 2023-10-03   -0.396280
# 2023-10-04    2.951672
# 2023-10-05    0.057188
# 2023-10-06   -0.790842
# Freq: D, Name: A, dtype: float64
#
# Selecting by label (row 0):
# A   -0.524242
# B   -0.821507
# C    0.325064
# D    0.851786
# Name: 2023-10-01 00:00:00, dtype: float64
#
# Selecting by position (row 1):
# A   -1.072816
# B    0.967339
# C   -0.053552
# D    1.444969
# Name: 2023-10-02 00:00:00, dtype: float64
#
# Selecting a subset of rows and columns:
#                    A         B
# 2023-10-02 -1.072816  0.967339
# 2023-10-03 -0.396280  2.787754
# ========================================

# %%
# Missing Data
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1


print("Missing Data:")
print("DataFrame with missing values:")
print(df1)
print("\nDropping rows with missing values:")
print(df1.dropna())
print("\nFilling missing values:")
print(df1.fillna(value=0))
print("="*60)
# Out:
# Missing Data:
# DataFrame with missing values:
#                    A         B         C         D    E
# 2023-10-01 -0.062937  0.372422 -0.576213 -1.677258  1.0
# 2023-10-02  0.382352 -0.245340 -0.115292  1.088438  1.0
# 2023-10-03 -3.315692 -0.135003 -1.218170  0.067759  NaN
# 2023-10-04 -1.433835 -1.062141  1.421303 -0.623697  NaN
#
# Dropping rows with missing values:
#                    A         B         C         D    E
# 2023-10-01 -0.062937  0.372422 -0.576213 -1.677258  1.0
# 2023-10-02  0.382352 -0.245340 -0.115292  1.088438  1.0
#
# Filling missing values:
#                    A         B         C         D    E
# 2023-10-01 -0.062937  0.372422 -0.576213 -1.677258  1.0
# 2023-10-02  0.382352 -0.245340 -0.115292  1.088438  1.0
# 2023-10-03 -3.315692 -0.135003 -1.218170  0.067759  0.0
# 2023-10-04 -1.433835 -1.062141  1.421303 -0.623697  0.0
# ============================================================

# %%
# Operations
print("Operations:")
print("Mean of each column:")
print(df.mean())
print("\nSum of each row:")
print(df.sum(axis=1))
print("="*40)
# Out:
# Operations:
# Mean of each column:
# A   -0.617758
# B   -0.675167
# C    0.000901
# D    0.013108
# dtype: float64
#
# Sum of each row:
# 2023-10-01   -1.943986
# 2023-10-02    1.110158
# 2023-10-03   -4.601107
# 2023-10-04   -1.698369
# 2023-10-05   -0.801796
# 2023-10-06    0.261603
# Freq: D, dtype: float64
# ========================================

# %%
# Merge
left = pd.DataFrame({'key' : ['K0', 'K1', 'K2','K3'], 'A' : ['A0', 'A1', 'A2', 'A3'], 'B': ['B0', 'B1', 'B2', 'B3']})
right = pd.DataFrame({'key' : ['K0', 'K1', 'K2', 'K3'], 'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']})
merged_df = pd.merge(left, right, on='key')

print("Merge:")
print("Merged DataFrame:")
print(merged_df)
print("="*40)
# Out:
# Merge:
# Merged DataFrame:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3
# ========================================

# %%
# Grouping
grouped =  df.groupby('A').sum()
print("Grouping:")
print("Grouped DataFrame:")
print(grouped)
print("="*40)
# Out:
# Grouping:
# Grouped DataFrame:
#                   B         C         D
# A
# -1.072816  0.967339 -0.053552  1.444969
# -0.790842 -0.213585 -1.531817 -2.501583
# -0.524242 -0.821507  0.325064  0.851786
# -0.396280  2.787754 -0.068282  0.384901
#  0.057188  0.036190  0.866765  2.122833
#  2.951672 -0.391658 -0.299577 -1.154125
# ========================================

# %%
# Reshaping
stacked = df.stack()
unstacked = stacked.unstack()

print("Reshaping:")
print("Stacked DataFrame:")
print(stacked)
print("\nUnstacked DataFrame:")
print(unstacked)
print("="*40)
# Out:
# Reshaping:
# Stacked DataFrame:
# 2023-10-01  A   -0.524242
#             B   -0.821507
#             C    0.325064
#             D    0.851786
# 2023-10-02  A   -1.072816
#             B    0.967339
#             C   -0.053552
#             D    1.444969
# 2023-10-03  A   -0.396280
#             B    2.787754
#             C   -0.068282
#             D    0.384901
# 2023-10-04  A    2.951672
#             B   -0.391658
#             C   -0.299577
#             D   -1.154125
# 2023-10-05  A    0.057188
#             B    0.036190
#             C    0.866765
#             D    2.122833
# 2023-10-06  A   -0.790842
#             B   -0.213585
#             C   -1.531817
#             D   -2.501583
# dtype: float64
#
# Unstacked DataFrame:
#                    A         B         C         D
# 2023-10-01 -0.524242 -0.821507  0.325064  0.851786
# 2023-10-02 -1.072816  0.967339 -0.053552  1.444969
# 2023-10-03 -0.396280  2.787754 -0.068282  0.384901
# 2023-10-04  2.951672 -0.391658 -0.299577 -1.154125
# 2023-10-05  0.057188  0.036190  0.866765  2.122833
# 2023-10-06 -0.790842 -0.213585 -1.531817 -2.501583
# ========================================

# %%
# Time Series
ts = pd.Series(np.random.randn(1000), index=pd.date_range('2023-01-01', periods=1000))
cumulative_sum = ts.cumsum()

print("Time Series:")
print(ts.head())
print("\nCumulative Sum:")
print(cumulative_sum.head())
print("="*40)
# Out:
# Time Series:
# 2023-01-01   -1.735813
# 2023-01-02   -2.095660
# 2023-01-03    1.110576
# 2023-01-04    0.241495
# 2023-01-05   -0.314945
# Freq: D, dtype: float64
#
# Cumulative Sum:
# 2023-01-01   -1.735813
# 2023-01-02   -3.831473
# 2023-01-03   -2.720897
# 2023-01-04   -2.479402
# 2023-01-05   -2.794347
# Freq: D, dtype: float64
# ========================================

# %%
# categoricals
import pandas as pd

# Create a categorical Series
s = pd.Series(["cat", "dog", "cat", "dog"], dtype="category")

#Define new categories
new_categories = ["Category 1", "Category 2", "Category 3"]

#Create a new categorical Series with the new categories
s_new = s.cat.set_categories(new_categories)

print("Categoricals:")
print("Original Categorical Series:")
print(s)
print("\nNew Categorical Series with updated categories:")
print(s_new)
# Out:
# Categoricals:
# Original Categorical Series:
# 0    cat
# 1    dog
# 2    cat
# 3    dog
# dtype: category
# Categories (2, object): ['cat', 'dog']
#
# New Categorical Series with updated categories:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# dtype: category
# Categories (3, object): ['Category 1', 'Category 2', 'Category 3']

# %%
import matplotlib.pyplot as plt
# Plotting
df.plot()
plt.show()

print("plotting:")
print("="*40)
# Out:
# plotting:
# ========================================

# %%
# Importing and Exporting Data
imported_df = pd.read_csv('/content/sample_data.csv')

print("Importing and Exporting Data:")
print("Exported DataFrame to CSV:")
print(df)
print("\nImported DataFrame from CSV:")
print(imported_df)
print("="*40)
df.to_csv('sampel_data2..csv')
# Out:
# Importing and Exporting Data:
# Exported DataFrame to CSV:
#                    A         B         C         D
# 2023-10-01 -0.524242 -0.821507  0.325064  0.851786
# 2023-10-02 -1.072816  0.967339 -0.053552  1.444969
# 2023-10-03 -0.396280  2.787754 -0.068282  0.384901
# 2023-10-04  2.951672 -0.391658 -0.299577 -1.154125
# 2023-10-05  0.057188  0.036190  0.866765  2.122833
# 2023-10-06 -0.790842 -0.213585 -1.531817 -2.501583
#
# Imported DataFrame from CSV:
#     SUBJECT Stim1 Stim2  Response
# 0         1     B     D         5
# 1         1     A     B         1
# 2         1     B     C         7
# 3         2     A     C         3
# 4         2     A     B         2
# 5         2     B     C         6
# 6         3     B     C         6
# 7         3     C     D         5
# 8         3     A     B         3
# 9         4     B     D         2
# 10        4     A     D         2
# 11        4     B     C         5
# 12        5     C     D         6
# 13        5     A     D         1
# 14        5     A     B         2
# 15        6     A     B         2
# 16        6     A     D         2
# 17        6     B     D         3
# 18        7     A     D         1
# 19        7     B     D         5
# 20        7     A     B         1
# 21        8     C     D         5
# 22        8     A     C         4
# 23        8     A     B         3
# 24        9     A     D         2
# 25        9     A     B         1
# 26        9     C     D         5
# 27       10     A     C         5
# 28       10     B     C         7
# 29       10     A     B         2
# ========================================
