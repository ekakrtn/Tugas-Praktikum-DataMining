# %% [markdown]
# <a href="https://colab.research.google.com/github/ekakrtn/Tugas-Praktikum-DataMining/blob/main/TugasDM_Praktikum11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas statsmodels
import pandas as pd
import statsmodels.api as sm
df = pd.read_csv('Data Penjualan Toko Buku.csv',sep = ',')
df.rename(columns={'jumlah':'Jumlah item'}, inplace=True)
df.rename(columns={'total':'Jumlah Transaksi'}, inplace=True)
df
# Out:
# ...
#       id_transaksi       jenis_item  Jumlah item tanggal pembelian  \
# 0         133889.0       Alat Tulis            1          1/1/2010
# 1         133889.0     Buku Sejarah            1          1/1/2010
# 2         133889.0   Buku Anak-Anak            2          1/1/2010
# 3         133889.0  Majalah Fashion            1          1/1/2010
# 4         133889.0   Majalah Berita            2          1/1/2010
# ...            ...              ...          ...               ...
# 3235           NaN              NaN            2         4/30/2024
# 3236           NaN              NaN            6         4/30/2024
# 3237           NaN              NaN            1         4/30/2024
# 3238           NaN              NaN            9         4/30/2024
# 3239           NaN              NaN            1         4/30/2024
#
#      nama_customer  Jumlah Transaksi
# 0     Stacy Campos          120000.0
# 1     Stacy Campos          150000.0
# 2     Stacy Campos          400000.0
# ...

# %%
df = df.dropna()

# %%
# Membersihkan data
df['Jumlah item'] = pd.to_numeric(df['Jumlah item'], errors='coerce')  # Pastikan kolom numerik
df['Jumlah Transaksi'] = pd.to_numeric(df['Jumlah Transaksi'], errors='coerce')  # Pastikan kolom numerik
df = df.dropna()
# Out:
# <ipython-input-14-c80585d7e472>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jumlah item'] = pd.to_numeric(df['Jumlah item'], errors='coerce')  # Pastikan kolom numerik
# <ipython-input-14-c80585d7e472>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jumlah Transaksi'] = pd.to_numeric(df['Jumlah Transaksi'], errors='coerce')  # Pastikan kolom numerik

# %%
#Statistik deskriptif
df.describe()
# Out:
#         id_transaksi  Jumlah item  Jumlah Transaksi
# count    2464.000000  2464.000000      2.464000e+03
# mean   134091.912338     4.967127      2.296528e+06
# std       116.390220     2.596911      2.786531e+06
# min    133889.000000     1.000000      2.000000e+04
# 25%    133992.000000     3.000000      2.250000e+05
# 50%    134091.000000     5.000000      1.170000e+06
# 75%    134192.000000     7.000000      3.250000e+06
# max    134294.000000     9.000000      1.215000e+07

# %%
# Menentukan variabel independen dan dependen
X = df['Jumlah item']
y = df['Jumlah Transaksi']

# %%
# Menambahkan konstanta
X = sm.add_constant(X)

# %%
# Membuat model OLS
model = sm.OLS(y, X).fit()

# %%
# Menampilkan hasil
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Jumlah Transaksi   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     2195.
# Date:                Wed, 25 Dec 2024   Prob (F-statistic):               0.00
# Time:                        09:00:39   Log-Likelihood:                -39277.
# No. Observations:                2464   AIC:                         7.856e+04
# Df Residuals:                    2462   BIC:                         7.857e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.363e+06   8.81e+04    -15.463      0.000   -1.54e+06   -1.19e+06
# ...
